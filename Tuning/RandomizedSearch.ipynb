# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('species' , axis=1)

# %%
y=df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_KNN=KNeighborsClassifier(n_neighbors=11)

# %%
model_KNN.fit(X_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
y_knn=model_KNN.predict(X_test)

# %%
accuracy_score(y_test , y_knn)  #Testing accuracy
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_SVM=SVC(C=10 , gamma='auto' , kernel='linear')

# %%
model_SVM.fit(X_train , y_train)
# Out:
# SVC(C=10, gamma='auto', kernel='linear')

# %%
y_svm=model_SVM.predict(X_test)

# %%
accuracy_score(y_test , y_svm)
# Out:
# 1.0

# %%
### IMPLEMENTING GRID SEARCH CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
model_SVM2=SVC(gamma='auto') # for gscv , just model should exist , not trained.

# %%
classifier=GridSearchCV((model_SVM2) ,
                        {
                            'C' : [1,10,20,30],
                            'kernel' : ['rbf' , 'linear']
                        },
                        cv=5,
                        return_train_score=False
                        )

# %%
classifier.fit(X,y) # In Cross validation(CV) , only Real x and y are passed( not the train test spit one.)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00286512, 0.00259132, 0.002736  , 0.00244074, 0.00245142,
#         0.00240951, 0.00256371, 0.00255971]),
#  'std_fit_time': array([3.67079991e-04, 2.97296760e-04, 1.63804953e-04, 1.72463134e-04,
#         3.76806969e-05, 1.14737999e-04, 2.94641573e-04, 3.78438992e-04]),
#  'mean_score_time': array([0.00210075, 0.00182781, 0.00205097, 0.00182858, 0.00179596,
#         0.00182796, 0.00176582, 0.00182557]),
#  'std_score_time': array([3.39774646e-04, 5.17133361e-05, 2.05214482e-04, 6.43559893e-05,
#         1.46128612e-05, 1.02307965e-04, 4.42769941e-05, 1.13210521e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
# ...

# %%
results=pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.002865      0.000367         0.002101        0.000340        1
# 1       0.002591      0.000297         0.001828        0.000052        1
# 2       0.002736      0.000164         0.002051        0.000205       10
# 3       0.002441      0.000172         0.001829        0.000064       10
# 4       0.002451      0.000038         0.001796        0.000015       20
# 5       0.002410      0.000115         0.001828        0.000102       20
# 6       0.002564      0.000295         0.001766        0.000044       30
# 7       0.002560      0.000378         0.001826        0.000113       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C' , 'param_kernel' , 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
print(classifier.best_params_)
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
print(classifier.best_score_)
# Out:
# 0.9800000000000001

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier2=RandomizedSearchCV((model_SVM2) ,
                        {
                            'C' : [1,10,20,30],
                            'kernel' : ['rbf' , 'linear']
                        },
                        n_iter=2,
                        cv=5,
                        return_train_score=False
                        )

# %%
classifier2.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=2,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
results2=pd.DataFrame(classifier2.cv_results_)

# %%
results2[['param_C' , 'param_kernel' , 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       30          rbf         0.960000
# 1       20       linear         0.966667

# %%
print(classifier2.best_params_)
# Out:
# {'kernel': 'linear', 'C': 20}

# %%
print(classifier2.best_score_)
# Out:
# 0.9666666666666666
